# %% [markdown]
# # Time Series Case study
#    Amit Patel
#    Sanjay Jagalaramudi
#    Murali Parthasarathy
#
# Objective -  The objective of this case study is to understand the concepts of time series and models like Rolling contract analysis and Signal Frontier Analysis
#
# The analysis is done as follows
#
# - Data was imported from the google financial web site. The team selected the following stocks
# BAC - Bank of America
# APPL - Apple
# GOOG . - Google
# BCS . - Barclays
# AMZ - Amazon

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%m/%d/%Y')
dataCase4 = pd.read_csv('/users/murali/quantWorld/TimeSeries/CaseStudy2/CaseStudy4_all_stocks.csv',parse_dates=['Date'], index_col='Date',date_parser=dateparse)

# %%
tempTS = dataCase4[['Stock','Adj Close']]

# %%
BACTS = tempTS[tempTS['Stock'] == 'BAC']

# %%
GOOGTS = tempTS[tempTS['Stock'] == 'GOOG']

# %%
YHOOTS = tempTS[tempTS['Stock'] == 'YHOO']

# %%
BCSTS  = tempTS[tempTS['Stock'] == 'BCS']

# %%
AMZNTS = tempTS[tempTS['Stock'] == 'AMZN']

# %%
BACTS.plot()

# %% [markdown]
# The graph shows the performance of Bank of America over a period of 15 years.

# %%
BACTS.ix['2016'].plot()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# The 2016 plot of Bank of America shows a constant rist aofter 09 2016

# %%
GOOGTS.plot()

# %% [markdown]
# The plot shows the performance of google over a period of 15 years

# %%
GOOGTS.ix['2016'].plot()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Google performance for the year 2016

# %%
AMZNTS.ix['01-2016':'03-2016'].plot()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Amazon daily prices in the first quarter of 2016

# %%
# Sample Code 
#d = {'one' : pd.Series([1., 2., 3.], index=['a', 'b', 'c']),
 #  ....:      'two' : pd.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])}

# %%
#ts = pd.DataFrame({'BAC' : pd.Series(BACTS) },{'GOOG' : pd.Series(GOOGTS)})

#pd.Series(BACTS['Adj Close'])

#ts = pd.DataFrame({'BAC' : pd.Series(BACTS['Adj Close']) ,'GOOG' : pd.Series(GOOGTS['Adj Close']) ,'YHOO' : pd.Series(YHOOTS['Adj Close']) }
 #                ,'BCS' : pd.Series(BCSTS['Adj Close']),'AMZN' : pd.Series(AMZNTS['Adj Close']) )

# %%
ts = pd.DataFrame({'BAC' : pd.Series(BACTS['Adj Close']) ,'GOOG' : pd.Series(GOOGTS['Adj Close']) ,'YHOO' : pd.Series(YHOOTS['Adj Close']) 
                 ,'BCS' : pd.Series(BCSTS['Adj Close']),'AMZN' : pd.Series(AMZNTS['Adj Close']) } )

# %%
#In [117]: px = px.asfreq('B').fillna(method='pad')

#In [118]: rets = px.pct_change()

#In [119]: ((1 + rets).cumprod() - 1).plot()

# %%
ts.ix['2016'].plot()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Comparison of all stocks in 2016

# %% [markdown]
# Plotting a quarterly frequency for all stocks for the Year of 2016

# %%
tsquart = ts

# %%
tsquartAll = ts.resample('Q-DEC', fill_method='ffill')
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: fill_method is deprecated to .resample()
# the new syntax is .resample(...).ffill()
#   """Entry point for launching an IPython kernel.

# %%
tsquartAll.ix['2016'].plot()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Moving Window function to review the mean and variance of the closing prices

# %%
 pd.rolling_mean(ts.ix['2011'], 40).plot()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=40,center=False).mean()
#   """Entry point for launching an IPython kernel.

# %%
 pd.rolling_std(ts.ix['2011'], 250, min_periods = 10).plot()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.rolling_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(min_periods=10,window=250,center=False).std()
#   """Entry point for launching an IPython kernel.

# %%
#Moving Window Functions 
# Calculate the rolling mean and Standard

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=True,
                         figsize=(12, 7))

ts_px = ts.ix['2011':'2016']

ma60 = pd.rolling_mean(ts_px, 60, min_periods=50)
ewma60 = pd.ewma(ts_px, span=60)

ts_px.plot(style='k-', ax=axes[0])
ma60.plot(style='k--', ax=axes[0])
ts_px.plot(style='k-', ax=axes[1])
ewma60.plot(style='k--', ax=axes[1])
axes[0].set_title('Simple MA')
axes[1].set_title('Exponentially-weighted MA')
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(min_periods=50,window=60,center=False).mean()
#
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,span=60,min_periods=0,adjust=True).mean()
#   import sys

# %%
 px = ts.asfreq('B').fillna(method='pad')

# %%
rets = px.pct_change()

# %%
((1 + rets).cumprod() - 1).plot()

# %%
from __future__ import division

# %%
import __future__
import __future__

# %%
import __future__
def calc_mom(price, lookback, lag):
    print ("CalcMom")
    mom_ret = price.shift(lag).pct_change(lookback)
    print mom_ret
    print mom_ret
    ranks = mom_ret.rank(axis=1, ascending=False)
    demeaned = ranks - ranks.mean(axis=1)
    return demeaned / demeaned.std(axis=1)
compound = lambda x : (1 + x).prod() - 1
 
daily_sr = lambda x: x.mean() / x.std()
 
def strat_sr(prices, lb, hold):
    print("Hello")
    #print prices
    #print hold
    # Compute portfolio weights
    freq = '%dB' % hold
    #print freq
    port = calc_mom(prices, lb, lag=1)
    print port
    print prices

    daily_rets = prices.pct_change()

    # Compute portfolio returns
    port = port.shift(1).resample(freq, how='first')
    #returns = daily_rets.resample(freq, how='compound')
    #port_rets = (port * returns).sum(axis=1)

    #return daily_sr(port_rets) * np.sqrt(252 / hold)

# %%
#daily_sr(px)

# %%
hold=10
freq = '%dB' % hold
print freq
# Out:
# 10B

# %%
strat_sr(px,5,7)
# Out:
# Hello
# CalcMom
#                 AMZN       BAC       BCS      GOOG      YHOO
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN
# 2010-01-05       NaN       NaN       NaN       NaN       NaN
# 2010-01-06       NaN       NaN       NaN       NaN       NaN
# 2010-01-07       NaN       NaN       NaN       NaN       NaN
# 2010-01-08       NaN       NaN       NaN       NaN       NaN
# 2010-01-11       NaN       NaN       NaN       NaN       NaN
# 2010-01-12 -0.026811  0.079031  0.125477 -0.040909 -0.021053
# 2010-01-13 -0.054496  0.009877  0.051190 -0.053703 -0.031921
# 2010-01-14 -0.023743  0.014033  0.053381 -0.034804 -0.015725
# 2010-01-15 -0.020385 -0.006497  0.028432 -0.007154  0.025150
# 2010-01-18 -0.047783 -0.030989 -0.013605 -0.036577  0.007186
# 2010-01-19 -0.024327 -0.039575 -0.015996 -0.035118  0.004779
# 2010-01-20  0.002042 -0.002445  0.011805 -0.004844  0.004197
# 2010-01-21 -0.025792 -0.007822 -0.045367 -0.011378 -0.030769
# ...

# %%
from __future__ import division
import __future__
strat_sr(px, 70, 30)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:21: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).first()
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:22: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-86-e0fb189b300b> in <module>()
#       1 from __future__ import division
#       2 import __future__
# ----> 3 strat_sr(px, 70, 30)
#       4
#
# <ipython-input-83-f738c17e39a2> in strat_sr(prices, lb, hold)
#      23     port_rets = (port * returns).sum(axis=1)
#      24
# ---> 25     return daily_sr(port_rets) * np.sqrt(252 / hold)
#
# <ipython-input-83-f738c17e39a2> in <lambda>(x)
#       7 compound = lambda x : (1 + x).prod() - 1
#       8 #try:
# ----> 9 daily_sr = lambda x: x.mean() / x.std()
# ...

# %%
import __future__
from collections import defaultdict

lookbacks = range(20, 90, 5)
holdings = range(20, 90, 5)
dd = defaultdict(dict)
for lb in lookbacks:
    for hold in holdings:
        dd[lb][hold] = strat_sr(px, lb, hold)

ddf = DataFrame(dd)
ddf.index.name = 'Holding Period'
ddf.columns.name = 'Lookback Period'
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:21: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).first()
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:22: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-77-65a029378696> in <module>()
#       7 for lb in lookbacks:
#       8     for hold in holdings:
# ----> 9         dd[lb][hold] = strat_sr(px, lb, hold)
#      10
#      11 ddf = DataFrame(dd)
#
# <ipython-input-75-f738c17e39a2> in strat_sr(prices, lb, hold)
#      23     port_rets = (port * returns).sum(axis=1)
#      24
# ---> 25     return daily_sr(port_rets) * np.sqrt(252 / hold)
#
# <ipython-input-75-f738c17e39a2> in <lambda>(x)
#       7 compound = lambda x : (1 + x).prod() - 1
#       8 #try:
# ...

# %%
import matplotlib.pyplot as plt

def heatmap(df, cmap=plt.cm.gray_r):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    axim = ax.imshow(df.values, cmap=cmap, interpolation='nearest')
    ax.set_xlabel(df.columns.name)
    ax.set_xticks(np.arange(len(df.columns)))
    ax.set_xticklabels(list(df.columns))
    ax.set_ylabel(df.index.name)
    ax.set_yticks(np.arange(len(df.index)))
    ax.set_yticklabels(list(df.index))
    plt.colorbar(axim)

# %%
heatmap(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-aeb179162431> in <module>()
# ----> 1 heatmap(df)
#
# NameError: name 'df' is not defined

# %% [markdown]
#     Future Contract Method

# %%
from datetime import datetime
expiry = {'ESU2': datetime(2012, 9, 21),
          'ESZ2': datetime(2012, 12, 21)}

expiry = pd.Series(expiry)
expiry = expiry.sort_values()
#expiry = pd.Series(expiry).order()

# %%
np.random.seed(12347)
N = 200
walk = (np.random.randint(0, 200, size=N) - 100) * 0.25
perturb = (np.random.randint(0, 20, size=N) - 10) * 0.25
walk = walk.cumsum()

rng = pd.date_range(px.index[0], periods=len(px) + N, freq='B')
near = np.concatenate([px.values, px.values[-1] + walk])
far = np.concatenate([px.values, px.values[-1] + walk + perturb])
prices = DataFrame({'ESU2': near, 'ESZ2': far}, index=rng)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-104c122880d5> in <module>()
#       6
#       7 rng = pd.date_range(px.index[0], periods=len(px) + N, freq='B')
# ----> 8 near = np.concatenate([px.values, px.values[-1] + walk])
#       9 far = np.concatenate([px.values, px.values[-1] + walk + perturb])
#      10 prices = DataFrame({'ESU2': near, 'ESZ2': far}, index=rng)
#
# ValueError: operands could not be broadcast together with shapes (5,) (200,)
